# %%
# !git clone https://github.com/keras-team/keras-tuner

# %%
cd keras-tuner

# %%
# !pip install .

# %%
# Train a DNN model for prediction

import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import kerastuner as kt



# upload the data base at the certain path
data = pd.read_csv('/content/trainset.csv')  
x_train = data.loc[0:506, ['A','B','C','D','E','F']]
x_train=np.array(x_train)
y_train = data.loc[0:506, ['target']]
y_train=np.array(y_train)

#Define model
def model_builder(hp):
  model = keras.Sequential()
#Set the input layer
  model.add(keras.layers.Flatten(input_shape=(6,1)))
#In here, we tuner the number of layers using for loop
  for i in range(hp.Int('num_layers', 2 , 5)):
    model.add(keras.layers.Dense(units=hp.Int('units_' + str(i),
                      min_value=6,
                      max_value=50,
                      step=1),
                activation= 'relu'))
  model.add(keras.layers.Dense(1, activation='linear'))
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(
         optimizer=tf.keras.optimizers.RMSprop(lr=hp_learning_rate, rho=0.9, epsilon=1e-06),
              loss='mean_absolute_error',
              metrics=['mean_absolute_error'])
  return model
       

tuner = kt.RandomSearch(model_builder,
                     objective='val_mean_absolute_error',
                     max_trials=5,
                     executions_per_trial=3,
                     directory='my_dir',
                     project_name='kerastuner')
# represent the search space
tuner.search_space_summary()

# search the best hyperparameters
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
tuner.search(x_train,y_train,epochs=50,validation_split=0.2,callbacks=[stop_early])

# recall the overall hyperparameters
tuner.results_summary()

# train model with the best hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
model = tuner.hypermodel.build(best_hps)

#manifest the model structure
model.summary()

#extract the best hyperparameters 
tuner.oracle.get_best_trials(num_trials=1)[0].hyperparameters.values
# Out:
# Trial 5 Complete [00h 00m 06s]
# val_mean_absolute_error: 5.422041416168213
#
# Best val_mean_absolute_error So Far: 3.5399559338887534
# Total elapsed time: 00h 00m 41s
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in my_dir/kerastuner
# Showing 10 best trials
# Objective(name='val_mean_absolute_error', direction='min')
# Trial summary
# Hyperparameters:
# num_layers: 4
# units_0: 46
# units_1: 45
# learning_rate: 0.001
# units_2: 31
# units_3: 33
# units_4: 21
# Score: 3.5399559338887534
# Trial summary
# Hyperparameters:
# num_layers: 4
# units_0: 20
# units_1: 36
# learning_rate: 0.01
# units_2: 37
# units_3: 38
# units_4: 28
# Score: 4.13828166325887
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 20
# units_1: 17
# learning_rate: 0.0001
# units_2: 39
# units_3: 6
# units_4: 6
# Score: 5.417775313059489
# Trial summary
# Hyperparameters:
# num_layers: 4
# units_0: 28
# units_1: 11
# learning_rate: 0.0001
# units_2: 40
# units_3: 46
# units_4: 10
# Score: 5.422041416168213
# Trial summary
# Hyperparameters:
# num_layers: 3
# units_0: 20
# units_1: 40
# learning_rate: 0.0001
# units_2: 6
# Score: 9.335944016774496
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 6)                 0
# _________________________________________________________________
# dense (Dense)                (None, 46)                322
# _________________________________________________________________
# dense_1 (Dense)              (None, 45)                2115
# _________________________________________________________________
# dense_2 (Dense)              (None, 31)                1426
# _________________________________________________________________
# dense_3 (Dense)              (None, 33)                1056
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 34
# =================================================================
# Total params: 4,953
# Trainable params: 4,953
# Non-trainable params: 0
# _________________________________________________________________
# {'learning_rate': 0.001,
#  'num_layers': 4,
#  'units_0': 46,
#  'units_1': 45,
#  'units_2': 31,
#  'units_3': 33,
#  'units_4': 21}

# %%
# !pip3 install pygad

# %%
# Optimization for input features

import numpy as np
import pygad

#define fitness function
def fitness_func(solution, solution_idx):
    # solution[i] represeent the value of the (i+1)th parameter in solution
    solution=np.empty(shape=(1,6))
    output=model(solution) # model is built in keras.tuner
    fitness =1/(output)
    return fitness

# Number of generations.
num_generations = 50 
# Number of solutions to be selected as parents in the mating pool.
num_parents_mating = 5 
# Number of solutions in the population.
sol_per_pop = 10 
  
# Type of parent selection.
parent_selection_type = "sss"
# Type of the crossover operator.
crossover_type = "single_point" 
# Type of the mutation operator.
mutation_type = "random"

last_fitness = 0
def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    last_fitness = ga_instance.best_solution()[1]

# Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.
ga_instance = pygad.GA(
     #Number of generations(iterations).
     num_generations=num_generations,
     num_parents_mating=num_parents_mating,
     fitness_func=fitness_func,
     sol_per_pop=sol_per_pop,
     #the Number of parameters(the number of genes)
     num_genes=6,
     gene_space=[np.arange(0,2 ,0.01).tolist(),np.arange(2,10.01,0.01).tolist(),np.arange(2,10.01,0.01).tolist(),np.arange(2,15.01,0.01).tolist(),
                 np.arange(2,18.01,0.01).tolist(),np.arange(2,20.01,0.01).tolist()],
     
     parent_selection_type=parent_selection_type,
     keep_parents=1,
     crossover_type=crossover_type,
     mutation_percent_genes=50,
     mutation_type=mutation_type,
     callback_generation=callback_generation)

# Running the GA to optimize the parameters of the function.
ga_instance.run()


# After the generations complete, some plots are showed that summarize the how the outputs/fitenss values evolve over generations.
ga_instance.plot_result()

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=1/solution_fitness))
# Out:
# /usr/local/lib/python3.7/dist-packages/pygad/pygad.py:632: UserWarning: Starting from PyGAD 2.6.0, the callback_generation parameter is deprecated and will be removed in a later release of PyGAD. Please use the on_generation parameter instead.
#   if not self.suppress_warnings: warnings.warn("Starting from PyGAD 2.6.0, the callback_generation parameter is deprecated and will be removed in a later release of PyGAD. Please use the on_generation parameter instead.")
# Generation = 1
# Fitness    = [[-0.927528]]
# Change     = [[-0.927528]]
# Generation = 2
# Fitness    = [[-0.927528]]
# Change     = [[-0.02548432]]
# Generation = 3
# Fitness    = [[-0.95301235]]
# Change     = [[0.02886802]]
# Generation = 4
# Fitness    = [[-0.9241443]]
# Change     = [[-0.03575355]]
# Generation = 5
# Fitness    = [[-0.9598979]]
# Change     = [[0.03257048]]
# Generation = 6
# Fitness    = [[-0.9273274]]
# Change     = [[-0.04715347]]
# Generation = 7
# Fitness    = [[-0.97448087]]
# Change     = [[0.01983052]]
# Generation = 8
# Fitness    = [[-0.95465034]]
# Change     = [[-0.0221566]]
# Generation = 9
# Fitness    = [[-0.97680694]]
# Change     = [[0.04518872]]
# Generation = 10
# Fitness    = [[-0.9316182]]
# Change     = [[0.00043589]]
# Generation = 11
# Fitness    = [[-0.9546824]]
# Change     = [[0.01193893]]
# Generation = 12
# Fitness    = [[-0.9427435]]
# Change     = [[-0.03511924]]
# Generation = 13
# Fitness    = [[-0.9778627]]
# Change     = [[0.02231276]]
# Generation = 14
# Fitness    = [[-0.95554996]]
# Change     = [[-0.00270587]]
# Generation = 15
# Fitness    = [[-0.9582558]]
# Change     = [[0.00775766]]
# Generation = 16
# Fitness    = [[-0.95049816]]
# Change     = [[-0.01135188]]
# Generation = 17
# Fitness    = [[-0.96185005]]
# Change     = [[-0.00071943]]
# Generation = 18
# Fitness    = [[-0.9625695]]
# Change     = [[-0.00062519]]
# Generation = 19
# Fitness    = [[-0.96319467]]
# Change     = [[-0.0086872]]
# Generation = 20
# Fitness    = [[-0.97188187]]
# Change     = [[0.00768346]]
# Generation = 21
# Fitness    = [[-0.9641984]]
# Change     = [[0.01586181]]
# Generation = 22
# Fitness    = [[-0.9483366]]
# Change     = [[-0.01763117]]
# Generation = 23
# Fitness    = [[-0.9659678]]
# Change     = [[-0.01021183]]
# Generation = 24
# Fitness    = [[-0.9761796]]
# Change     = [[0.03321779]]
# Generation = 25
# Fitness    = [[-0.9429618]]
# Change     = [[-0.03729528]]
# Generation = 26
# Fitness    = [[-0.9802571]]
# Change     = [[0.04922235]]
# Generation = 27
# Fitness    = [[-0.93103474]]
# Change     = [[-0.03247601]]
# Generation = 28
# Fitness    = [[-0.96351075]]
# Change     = [[-0.00327593]]
# Generation = 29
# Fitness    = [[-0.9667867]]
# Change     = [[0.00989652]]
# Generation = 30
# Fitness    = [[-0.95689017]]
# Change     = [[0.01472902]]
# Generation = 31
# Fitness    = [[-0.94216114]]
# Change     = [[-0.02506417]]
# Generation = 32
# Fitness    = [[-0.9672253]]
# Change     = [[0.02161556]]
# Generation = 33
# Fitness    = [[-0.94560975]]
# Change     = [[-0.01340693]]
# Generation = 34
# Fitness    = [[-0.9590167]]
# Change     = [[0.01397359]]
# Generation = 35
# Fitness    = [[-0.9744041]]
# Change     = [[-0.02936101]]
# Generation = 36
# Fitness    = [[-0.9744041]]
# Change     = [[0.02530366]]
# Generation = 37
# Fitness    = [[-0.94910043]]
# Change     = [[-0.01505673]]
# Generation = 38
# Fitness    = [[-0.96415716]]
# Change     = [[0.0231384]]
# Generation = 39
# Fitness    = [[-0.94101876]]
# Change     = [[0.01088023]]
# Generation = 40
# Fitness    = [[-0.9301385]]
# Change     = [[-0.0037334]]
# Generation = 41
# Fitness    = [[-0.9326824]]
# Change     = [[0.00118953]]
# Generation = 42
# Fitness    = [[-0.9326824]]
# Change     = [[0.00077194]]
# Generation = 43
# Fitness    = [[-0.93191046]]
# Change     = [[-0.0135259]]
# Generation = 44
# Fitness    = [[-0.94543636]]
# Change     = [[0.00551134]]
# Generation = 45
# Fitness    = [[-0.939925]]
# Change     = [[-0.01150942]]
# Generation = 46
# Fitness    = [[-0.95143443]]
# Change     = [[-0.02063566]]
# Generation = 47
# Fitness    = [[-0.9720701]]
# Change     = [[0.02682656]]
# Generation = 48
# Fitness    = [[-0.94524354]]
# Change     = [[-0.01108372]]
# Generation = 49
# Fitness    = [[-0.95632726]]
# Change     = [[-0.01738214]]
# Generation = 50
# Fitness    = [[-0.9737094]]
# Change     = [[-0.00318354]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a1a7306d37d2> in <module>()
#      56
#      57 # After the generations complete, some plots are showed that summarize the how the outputs/fitenss values evolve over generations.
# ---> 58 ga_instance.plot_result()
#      59
#      60 # Returning the details of the best solution.
#
# /usr/local/lib/python3.7/dist-packages/pygad/pygad.py in plot_result(self, title, xlabel, ylabel, linewidth)
#    2530
#    2531         fig = matplotlib.pyplot.figure()
# -> 2532         matplotlib.pyplot.plot(self.best_solutions_fitness, linewidth=linewidth)
#    2533         matplotlib.pyplot.title(title)
#    2534         matplotlib.pyplot.xlabel(xlabel)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
# --> 345             raise ValueError(f"x and y can be no greater than 2-D, but have "
#     346                              f"shapes {x.shape} and {y.shape}")
#     347         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (51,) and (51, 1, 1)
